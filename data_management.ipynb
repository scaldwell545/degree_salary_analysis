# %%
# Dependencies and Setup
import pandas as pd
import csv
import os

# %%
# Files to Load
degrees_that_pay_back_path = os.path.join(os.getcwd(), "Resources", "degrees-that-pay-back.csv")
salaries_by_college_type_path = os.path.join(os.getcwd(), "Resources", "salaries-by-college-type.csv")
salaries_by_region_path = os.path.join(os.getcwd(), "Resources", "salaries-by-region.csv")

# %%
# Read Files and Store Into Pandas Data Frame
degrees_that_pay_back_df = pd.read_csv(degrees_that_pay_back_path)
salaries_by_college_type_df = pd.read_csv(salaries_by_college_type_path)
salaries_by_region_df = pd.read_csv(salaries_by_region_path)

# %%
# Take a peek
degrees_that_pay_back_df.head()
# Out:
#      Undergraduate Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# ...

# %%
salaries_by_college_type_df.head()
# Out:
#                                     School Name  School Type  \
# 0   Massachusetts Institute of Technology (MIT)  Engineering
# 1      California Institute of Technology (CIT)  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $76,800.00                        $99,200.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# ...

# %%
salaries_by_region_df.head()
# Out:
#                                 School Name   Region Starting Median Salary  \
# 0                       Stanford University  Western             $70,400.00
# 1  California Institute of Technology (CIT)  Western             $75,500.00
# 2                       Harvey Mudd College  Western             $71,800.00
# 3        University of California, Berkeley  Western             $59,900.00
# 4                        Occidental College  Western             $51,900.00
#
#   Mid-Career Median Salary Mid-Career 10th Percentile Salary  \
# 0              $129,000.00                        $68,400.00
# 1              $123,000.00                               NaN
# 2              $122,000.00                               NaN
# 3              $112,000.00                        $59,500.00
# 4              $105,000.00                               NaN
#
#   Mid-Career 25th Percentile Salary Mid-Career 75th Percentile Salary  \
# ...
